# %%
import requests

response = requests.get("https://pokeapi.co/api/v2/pokemon/garchomp")
data = response.json()

print(f"Name: {data['name']}")
print(f"Height: {data['height']}")
print(f"Weight: {data['weight']}")
print(f"Base Experience: {data['base_experience']}")
# Out:
# Name: garchomp
# Height: 19
# Weight: 950
# Base Experience: 270

# %%
import json
print(json.dumps(data, indent=2))
# Out:
# {
#   "abilities": [
#     {
#       "ability": {
#         "name": "sand-veil",
#         "url": "https://pokeapi.co/api/v2/ability/8/"
#       },
#       "is_hidden": false,
#       "slot": 1
#     },
#     {
#       "ability": {
#         "name": "rough-skin",
#         "url": "https://pokeapi.co/api/v2/ability/24/"
#       },
#       "is_hidden": true,
#       "slot": 3
#     }
#   ],
#   "base_experience": 270,
#   "cries": {
#     "latest": "https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/445.ogg",
#     "legacy": "https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/445.ogg"
#   },
#   "forms": [
#     {
#       "name": "garchomp",
#       "url": "https://pokeapi.co/api/v2/pokemon-form/445/"
#     }
#   ],
#   "game_indices": [
#     {
#       "game_index": 445,
#       "version": {
#         "name": "diamond",
#         "url": "https://pokeapi.co/api/v2/version/12/"
#       }
#     },
#     {
#       "game_index": 445,
# ...

# %%
print("Type:")
for type_info in data['types']:
    print(type_info['type']['name'])
# Out:
# Stats:
# dragon
# ground

# %%
print("Stats:")
for stat in data['stats']:
    print(stat['stat']['name'])
# Out:
# Stats:
# hp
# attack
# defense
# special-attack
# special-defense
# speed

# %%
print(data.keys())
# Out:
# dict_keys(['abilities', 'base_experience', 'cries', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_abilities', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
print(data['stats'][0].keys())
# Out:
# dict_keys(['base_stat', 'effort', 'stat'])
